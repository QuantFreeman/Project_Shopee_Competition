# %%
from keras.preprocessing import image
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.neighbors import KNeighborsClassifier
import os, shutil, glob, os.path
from PIL import Image as pil_image
from sklearn.decomposition import PCA
from tqdm import tqdm

import gc

import pickle

import nltk
import re
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %%
# Variable 

image.LOAD_TRUNCATED_IMAGES = True 
model = VGG16(weights='imagenet', include_top=False)
imdir = "data/train_images/"
df = pd.read_csv("data/train.csv")
y = df.label_group
number_clusters = 50

# %%
#add path to df
df['path'] = imdir + df.image

# %%
df.path[1]
# Out:
# 'data/train_images/00039780dfc94d01db8676fe789ecd05.jpg'

# %%
# Loop over files and get features
#filelist = glob.glob(os.path.join(imdir, '*.jpg'))
#filelist.sort()
featurelist = []
for i, imagepath in enumerate(df.path):
    print("    Status: %s / %s" %(i, len(df.path)), end="\r")
    img = image.load_img(imagepath, target_size=(224, 224))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = np.array(model.predict(img_data))
    featurelist.append(features.flatten())
# Out:
#     Status: 34249 / 34250

# %%
#save file into pickle
# with open("featurelist.txt", "wb") as fp:   #Pickling
#     pickle.dump(featurelist, fp)
 
# with open("test.txt", "rb") as fp:   # Unpickling
#     b = pickle.load(fp)

# %%
def get_image_predictions(df, x,y ,threshold = 3.4):
    if len(df) > 3:
        KNN = 50
    else : 
        KNN = 3
    #model = NearestNeighbors(n_neighbors = KNN)
    model = KNeighborsClassifier(n_neighbors= KNN)
    model.fit(x,y)
    distances, indices = model.kneighbors(x)
    predictions = []
    for k in range(x.shape[0]):
        idx = np.where(distances[k,] < threshold)[0]
        ids = indices[k,idx]
        posting_ids = df['posting_id'].iloc[ids].values
        predictions.append(posting_ids)
    del model, distances, indices
    gc.collect()
    return predictions


#text preds

def get_text_predictions(df, max_features = 25_000):
    stopwords_list = stopwords.words('english') + stopwords.words('indonesian')
    model = TfidfVectorizer(stop_words = stopwords_list, binary = True, max_features = max_features)
    
    text_embeddings = model.fit_transform(df['title']).toarray()
    preds = []
    # magic number
    CHUNK = 1024*4
    print('Finding similar titles...')
    # discern # of chunks
    CTS = len(df)//CHUNK
    if len(df)%CHUNK!=0: CTS += 1
    for j in range( CTS ):
        # start pos for chunk idx
        a = j*CHUNK
        # end pos for chunk idx
        b = (j+1)*CHUNK
        # change to end of input if necessary
        b = min(b,len(df))
        print('chunk',a,'to',b)
        # COSINE SIMILARITY DISTANCE
        # matrix multiply(text emb & transposed chunk) then transpose
        cts = np.matmul( text_embeddings, text_embeddings[a:b].T ).T
        for k in range(b-a):
            # find where cosine sim > 0.7
            IDX = np.where(cts[k,]>0.7)[0]
            # save to o
            o = df.iloc[IDX].posting_id.values
            # append to preds
            preds.append(o)
    # delet model/text emb
    del model,text_embeddings
    # garb collect
    gc.collect()
    return preds

#combine prediction into 1 row

def combine_predictions(row):
    x = np.concatenate([row['img_prediction'],     row['text_predictions']])
    return ' '.join( np.unique(x) )

def f1_score(y_true, y_pred):
    y_true = y_true.apply(lambda x: set(x.split()))
    y_pred = y_pred.apply(lambda x: set(x.split()))
    intersection = np.array([len(x[0] & x[1]) for x in zip(y_true, y_pred)])
    len_y_pred = y_pred.apply(lambda x: len(x)).values
    len_y_true = y_true.apply(lambda x: len(x)).values
    f1 = 2 * intersection / (len_y_pred + len_y_true)
    return f1

# %%
x1 = np.stack(featurelist, axis=0 )

# %%
#get image prediction 
preds = get_image_predictions(df, x1, y, threshold = 3.4)

# %%
#list every label targets
tmp = df.groupby(['label_group'])['posting_id'].unique().to_dict()
df['targets'] = df['label_group'].map(tmp)
df['targets'] = df['targets'].apply(lambda x: ' '.join(x))

# %%
df.head(50)
# Out:
#           posting_id                                 image       image_phash  \
# 0    train_129225211  0000a68812bc7e98c42888dfb1c07da0.jpg  94974f937d4c2433
# 1   train_3386243561  00039780dfc94d01db8676fe789ecd05.jpg  af3f9460c2838f0f
# 2   train_2288590299  000a190fdd715a2a36faed16e2c65df7.jpg  b94cb00ed3e50f78
# 3   train_2406599165  00117e4fc239b1b641ff08340b429633.jpg  8514fc58eafea283
# 4   train_3369186413  00136d1cf4edede0203f32f05f660588.jpg  a6f319f924ad708c
# 5   train_2464356923  0013e7355ffc5ff8fb1ccad3e42d92fe.jpg  bbd097a7870f4a50
# 6   train_1802986387  00144a49c56599d45354a1c28104c039.jpg  f815c9bb833ab4c8
# 7   train_1806152124  0014f61389cbaa687a58e38a97b6383d.jpg  eea7e1c0c04da33d
# 8     train_86570404  0019a3c6755a194cb2e2c12bfc63972e.jpg  ea9af4f483249972
# 9    train_831680791  001be52b2beec40ddc1d2d7fc7a68f08.jpg  e1ce953d1a70618f
# 10  train_1598329973  001d7f5d9a2fac714f4d5f37b3baffb4.jpg  bec8d09693634b4b
# 11  train_2496690777  001e11145b8e9bf5ac51110c0fdd8697.jpg  eab5c295966ac368
# 12  train_2771755203  001e11145b8e9bf5ac51110c0fdd8697.jpg  eab5c295966ac368
# 13   train_998568945  001f4c8331d0554d133b10d85b7fafb2.jpg  d8a6082bb93d2db5
# 14  train_4287573913  001f5580b058c6b8e33132190a757318.jpg  dc85e1750687f932
# 15  train_4196427721  002039aaf8618627a0442d5e89e5dda6.jpg  e98c873acc65946e
# 16  train_3009013664  0027aaf8dd8bdbf0e4f2c19024e436cf.jpg  b3cccc26cc3333cc
# 17  train_3054371232  00286d2760e433a8a01cbd9e056144f7.jpg  be85837b8ca44ad3
# 18  train_2985955659  002f978c58a44a00aadfca71c3cad2bb.jpg  bf38f0e083d7c710
# 19  train_2961381387  00303ad1c062fdeaf5f41b9ffb71a5fb.jpg  e48d9b652098efe1
# 20   train_999391364  00324695e37299a00b955674d984592b.jpg  a734d84d34702f37
# 21  train_2238403912  003524b70715bf6bfa00451ca08e66e0.jpg  ba35c44a3fb7c068
# 22  train_1396146683  0035b8fc42955c0fa2301b68e2ffe861.jpg  d5c0caa0aeb3b23e
# 23  train_1180155871  00369839c7d94411e54437b7cf59b603.jpg  bbc1c43ec3633ec0
# 24  train_1872347548  003906c6c6bba4cde15e5e854dba8f6d.jpg  f3e18c5ea14493e3
# 25   train_249329869  003a6fbbdf88f0f60dc074458911f01e.jpg  9a9a631adca50bda
# 26  train_2905529497  003c7129aef72ad3ae8af64eac5bfd29.jpg  ce4e2d3570721ab5
# 27  train_3466601092  004076b57135e761ab8b41d84acc4c94.jpg  aa2c0ee4eb6ba0cd
# 28  train_1572286671  00416d439a613fb6cbede5cfc95176e6.jpg  bb3fccc4c013c3e1
# 2   data/train_images/000a190fdd715a2a36faed16e2c6...
# 3   data/train_images/00117e4fc239b1b641ff08340b42...
# 4   data/train_images/00136d1cf4edede0203f32f05f66...
# 5   data/train_images/0013e7355ffc5ff8fb1ccad3e42d...
# 6   data/train_images/00144a49c56599d45354a1c28104...
# 7   data/train_images/0014f61389cbaa687a58e38a97b6...
# 8   data/train_images/0019a3c6755a194cb2e2c12bfc63...
# 9   data/train_images/001be52b2beec40ddc1d2d7fc7a6...
# 10  data/train_images/001d7f5d9a2fac714f4d5f37b3ba...
# 11  data/train_images/001e11145b8e9bf5ac51110c0fdd...
# 12  data/train_images/001e11145b8e9bf5ac51110c0fdd...
# 13  data/train_images/001f4c8331d0554d133b10d85b7f...
# 14  data/train_images/001f5580b058c6b8e33132190a75...
# 15  data/train_images/002039aaf8618627a0442d5e89e5...
# 16  data/train_images/0027aaf8dd8bdbf0e4f2c19024e4...
# 17  data/train_images/00286d2760e433a8a01cbd9e0561...
# 18  data/train_images/002f978c58a44a00aadfca71c3ca...
# 19  data/train_images/00303ad1c062fdeaf5f41b9ffb71...
# 20  data/train_images/00324695e37299a00b955674d984...
# 21  data/train_images/003524b70715bf6bfa00451ca08e...
# 22  data/train_images/0035b8fc42955c0fa2301b68e2ff...
# 23  data/train_images/00369839c7d94411e54437b7cf59...
# 24  data/train_images/003906c6c6bba4cde15e5e854dba...
# 25  data/train_images/003a6fbbdf88f0f60dc074458911...
# 26  data/train_images/003c7129aef72ad3ae8af64eac5b...
# 27  data/train_images/004076b57135e761ab8b41d84acc...
# 28  data/train_images/00416d439a613fb6cbede5cfc951...
# 29  data/train_images/00416d439a613fb6cbede5cfc951...
# 30  data/train_images/004811219262c545d74e427c5ea2...
# 31  data/train_images/004822e4ab7dd38455a134fb2f2d...
# 32  data/train_images/004e512a55c80c07ae0684c58f5f...
# 33  data/train_images/004ede0e328d05780813f8538574...
# 34  data/train_images/004ee5243d3dc2ae78cd8a1ec836...
# 35  data/train_images/0052b0b2e8233836f2875a14a980...
# 36  data/train_images/005742b269e0ea4b352235b084e8...
# 37  data/train_images/0059bcdf255a1b95feed3a2799fc...
# 38  data/train_images/005a507afe7092537e4c6243c4e0...
# 39  data/train_images/005bb468c673fb7f70319c120fb7...
# 40  data/train_images/0060be82f37ed53560e033dd1973...
# 41  data/train_images/0061fff53b6eba569fb383da29fd...
# 42  data/train_images/0062b7c015f3c821725dcf2087e8...
# 43  data/train_images/0062ecb6613287fde4d3a6542e2d...
# 44  data/train_images/0065dd4c4dacac6b41c11079dd1e...
# 45  data/train_images/006860e5c85173a4949a924ddcb5...
# 46  data/train_images/006f6bc53dc5696a5514fc4ba00b...
# 47  data/train_images/007084f5652dbddedb3ab371c209...
# 48  data/train_images/0075a4ad758adeda9c264e64fd1d...
# 49  data/train_images/007847916882fe2583b24428e8d6...
#
#                           img_prediction  \
# 0                      [train_129225211]
# 1                     [train_3386243561]
# 2                     [train_2288590299]
# 3                     [train_2406599165]
# 4                     [train_3369186413]
# 5                     [train_2464356923]
# 6                     [train_1802986387]
# 7                     [train_1806152124]
# 8                       [train_86570404]
# 9                      [train_831680791]
# 10                    [train_1598329973]
# 11  [train_2496690777, train_2771755203]
# 12  [train_2771755203, train_2496690777]
# 13                     [train_998568945]
# 14                    [train_4287573913]
# 15                    [train_4196427721]
# 16                    [train_3009013664]
# 17                    [train_3054371232]
# 18                    [train_2985955659]
# 19                    [train_2961381387]
# 20                     [train_999391364]
# 21                    [train_2238403912]
# 22                    [train_1396146683]
# 23                    [train_1180155871]
# 24                    [train_1872347548]
# 25                     [train_249329869]
# 26                    [train_2905529497]
# 27                    [train_3466601092]
# 28  [train_1572286671, train_3117535609]
# 29  [train_3117535609, train_1572286671]
# 30                    [train_1617041019]
# 31                    [train_2410183091]
# 32                    [train_1461445798]
# 33                    [train_1449570166]
# 34                    [train_1327117441]
# 35                    [train_1640409557]
# 36                    [train_2720300071]
# 37                    [train_3906985249]
# 38                    [train_4146813717]
# 39                    [train_4193869534]
# 40                    [train_2966264418]
# 41                     [train_961019399]
# 42                    [train_3697474443]
# 43                    [train_3350934785]
# 44                     [train_476982317]
# 45                    [train_1243594898]
# 46                    [train_2679824623]
# 47                     [train_140914082]
# 48                    [train_1164271328]
# 49                    [train_3743764071]
#
#                                               targets
# 0                    train_129225211 train_2278313361
# 1                   train_3386243561 train_3423213080
# 2                   train_2288590299 train_3803689425
# 3                   train_2406599165 train_3342059966
# 4                    train_3369186413 train_921438619
# 5   train_2464356923 train_2753295474 train_305884580
# 6   train_1802986387 train_1396161074 train_713073...
# 7                   train_1806152124 train_3227306976
# 8      train_86570404 train_2837452969 train_77364776
# 9                    train_831680791 train_3031035861
# 10  train_1598329973 train_841015183 train_4224502769
# 11  train_2496690777 train_2771755203 train_163818...
# 12  train_2496690777 train_2771755203 train_163818...
# 13                   train_998568945 train_3118756415
# 14  train_4287573913 train_1748125201 train_163362...
# 15  train_4196427721 train_1482447822 train_234660...
# 16                  train_3009013664 train_3448377589
# 17                  train_3054371232 train_2301578474
# 18  train_2985955659 train_3916258742 train_415673...
# 19  train_2961381387 train_3905491488 train_232256...
# 20                   train_999391364 train_4285884352
# 21                  train_2238403912 train_2095062361
# 22  train_1396146683 train_2843292969 train_422585...
# 23                  train_1180155871 train_3269870940
# 24  train_1872347548 train_998519723 train_1760578...
# 25  train_249329869 train_3427012881 train_3379174374
# 26                   train_2905529497 train_869563964
# 27                   train_3466601092 train_354147588
# 28  train_1572286671 train_3117535609 train_321977...
# 29  train_1572286671 train_3117535609 train_321977...
# 30                  train_1617041019 train_2772927896
# 31  train_2410183091 train_2529718493 train_304181113
# 32                  train_1461445798 train_1749322479
# 33  train_1449570166 train_3629891683 train_288100...
# 34  train_1327117441 train_1806470370 train_162947...
# 35  train_1640409557 train_2613418854 train_104774...
# 36  train_2720300071 train_120345533 train_1855665910
# 37  train_3906985249 train_174234095 train_8718242...
# 38  train_4146813717 train_2095066661 train_257277...
# 39                   train_4193869534 train_935952718
# 40                  train_2966264418 train_2483309946
# 41                   train_961019399 train_1705721973
# 42  train_3697474443 train_2003670906 train_942029375
# 43                  train_3350934785 train_1675185549
# 44  train_476982317 train_2844717002 train_3535948...
# 45  train_1243594898 train_59648443 train_24172736...
# 46  train_2679824623 train_3116514616 train_108162...
# 47                   train_140914082 train_1635325326
# 48                  train_1164271328 train_2631472883
# 49  train_3743764071 train_3172872581 train_238448...

# %%
text_predictions = get_text_predictions(df, max_features = 25_000)
# Out:
# Finding similar titles...
# chunk 0 to 4096
# chunk 4096 to 8192
# chunk 8192 to 12288
# chunk 12288 to 16384
# chunk 16384 to 20480
# chunk 20480 to 24576
# chunk 24576 to 28672
# chunk 28672 to 32768
# chunk 32768 to 34250

# %%
#get f1 score 
f1_img = f1_score(df.targets, df.img_prediction)
f1_text = f1_score(df.targets, df.text_predictions)

# %%
#df['text_predictions'] = text_predictions
#df['img_prediction'] = preds
#df['matches'] = df.apply(combine_predictions, axis=1)
#df['f1'] = f1

# %%
# Preparing Submission file
df_1[['posting_id', 'matches']].to_csv('submission.csv', index=False)

# %%
f1 = f1_score(df.targets, df.matches)

# %%
f1_img = f1_score(df.targets, df.img_prediction)
f1_text = f1_score(df.targets, df.text_predictions)

# %%
f1.mean()
# Out:
# 0.6288451402918852

# %%
df_1 = pd.read_csv('final_df.csv')
df_1.head()
# Out:
#          posting_id                                 image       image_phash  \
# 0   train_129225211  0000a68812bc7e98c42888dfb1c07da0.jpg  94974f937d4c2433
# 1  train_3386243561  00039780dfc94d01db8676fe789ecd05.jpg  af3f9460c2838f0f
# 2  train_2288590299  000a190fdd715a2a36faed16e2c65df7.jpg  b94cb00ed3e50f78
# 3  train_2406599165  00117e4fc239b1b641ff08340b429633.jpg  8514fc58eafea283
# 4  train_3369186413  00136d1cf4edede0203f32f05f660588.jpg  a6f319f924ad708c
#
#                                                title  label_group  \
# 0                          Paper Bag Victoria Secret    249114794
# 1  Double Tape 3M VHB 12 mm x 4,5 m ORIGINAL / DO...   2937985045
# 2        Maling TTS Canned Pork Luncheon Meat 397 gr   2395904891
# 3  Daster Batik Lengan pendek - Motif Acak / Camp...   4093212188
# 4                  Nescafe \xc3\x89clair Latte 220ml   3648931069
#
#                                                 path        img_prediction  \
# 0  data/train_images/0000a68812bc7e98c42888dfb1c0...   ['train_129225211']
# 1  data/train_images/00039780dfc94d01db8676fe789e...  ['train_3386243561']
# 2  data/train_images/000a190fdd715a2a36faed16e2c6...  ['train_2288590299']
# 3  data/train_images/00117e4fc239b1b641ff08340b42...  ['train_2406599165']
# 4  data/train_images/00136d1cf4edede0203f32f05f66...  ['train_3369186413']
#
#                              targets  \
# 0   train_129225211 train_2278313361
# 1  train_3386243561 train_3423213080
# 2  train_2288590299 train_3803689425
# 3  train_2406599165 train_3342059966
# 4   train_3369186413 train_921438619
#
#                                     text_predictions  \
# 0             ['train_129225211' 'train_2278313361']
# 1                               ['train_3386243561']
# 2                               ['train_2288590299']
# 3  ['train_2406599165' 'train_3576714541' 'train_...
# 4                               ['train_3369186413']
#
#                                              matches        f1
# 0                   train_129225211 train_2278313361  1.000000
# 1                                   train_3386243561  0.666667
# 2                                   train_2288590299  0.666667
# 3  train_1508100548 train_1744956981 train_240659...  0.250000
# 4                                   train_3369186413  0.666667

# %%
df.f1.mean()
# Out:
# 0.6288451402918852
